# %%
# ANNDL Homework 1 - Image Classification
# team: romano_ercolani
# Members: Romanò Francesco | Ercolani Antonio

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/MyDrive/CHALLENGE 1 - Image Classification
# Out:
# /gdrive/MyDrive/CHALLENGE 1 - Image Classification

# %%
import os
from PIL import Image
import tensorflow as tf
import numpy as np
import random
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.7.0

# %%
dataset_dir = 'training'

# %%
# Plot example images from dataset
labels = ['Apple','Blueberry','Cherry','Corn','Grape','Orange','Peach','Pepper','Potato','Raspberry','Soybean','Squash','Strawberry','Tomato']

num_row = len(labels)//2
num_col = len(labels)//num_row
fig, axes = plt.subplots(num_row, num_col, figsize=(2*num_row,15*num_col))
for i in range(len(labels)):
  if i < len(labels):
    class_imgs = next(os.walk('{}/{}/'.format(dataset_dir, labels[i])))[2]
    class_img = class_imgs[0]
    img = Image.open('{}/{}/{}'.format(dataset_dir, labels[i], class_img))
    ax = axes[i//num_col, i%num_col]
    ax.imshow(np.array(img))
    ax.set_title('{}'.format(labels[i]))
plt.tight_layout()
plt.show()

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
batch_size = 128

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from keras.applications.vgg16 import preprocess_input

#2 data generator since we aug ONLY the training set 
# IN THIS NOTEBOOK WE ADD A PREPROCESSING FUNCTION AD HOC FOR VGG16 ARCHITECTURE

train_data_gen = ImageDataGenerator(rotation_range=30,
                                    height_shift_range=50,
                                    width_shift_range=50,
                                    zoom_range=0.3,
                                    horizontal_flip=True,
                                    vertical_flip=True, 
                                    fill_mode='constant', cval=0, # IN CLASS fill_mode='reflect'
                                    validation_split=0.2,
                                    preprocessing_function=preprocess_input) # preprocessing added here

valid_data_gen = ImageDataGenerator(validation_split=0.2, preprocessing_function=preprocess_input) # preprocessing also in the validation set


aug_train_gen = train_data_gen.flow_from_directory(directory=dataset_dir,
                                         target_size=(256,256),
                                         color_mode='rgb',
                                         classes=None,
                                         class_mode='categorical',
                                         batch_size=batch_size,
                                         shuffle=True,
                                         seed=seed,
                                         subset='training')

valid_gen = valid_data_gen.flow_from_directory(directory=dataset_dir,
                                         target_size=(256, 256),
                                         color_mode='rgb',
                                         classes=None,
                                         class_mode='categorical',
                                         batch_size=batch_size,
                                         shuffle=True,
                                         seed=seed,
                                         subset='validation')
# Out:
# Found 14189 images belonging to 14 classes.
# Found 3539 images belonging to 14 classes.

# %%
#explore training set and validation set
#only the images from training set should appear augmented 

train_batch = next(aug_train_gen)
valid_batch = next(valid_gen)

fig, ax = plt.subplots(1, 7, figsize=(30,45))
for i in range(0,7):
  ax[i].imshow(np.uint8(train_batch[0][i]))
  ax[i].set_title("From training set")

fig, ax = plt.subplots(1, 7, figsize=(30,45))
for i in range(0,7):
  ax[i].imshow(np.uint8(valid_batch[0][i]))
  ax[i].set_title("From validation set")

# %%
# Data exploration: check class distribution in training and validation data
plt.figure(figsize=(15,5))
sns.histplot(data=pd.DataFrame(aug_train_gen.classes, columns=['digit']), x='digit', kde=True)
plt.title("Classes occurence in train data")
plt.show()

plt.figure(figsize=(15,5))
sns.histplot(data=pd.DataFrame(valid_gen.classes, columns=['digit']), x='digit', kde=True)
plt.title("Classes occurence in val data")
plt.show()

#Obs: class distribution is more or less preserved in train and val data

# %%
# Models metadata
input_shape = (256, 256, 3)
epochs = 200

# %% [markdown]
# # Transfer Learning VGG16

# %%
# Model transferred: vgg16
supernet = tfk.applications.VGG16(
    include_top=False,
    weights="imagenet",
    input_shape=(256, 256, 3)
)
supernet.summary()
tfk.utils.plot_model(supernet)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 58900480/58889256 [==============================] - 1s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Create the classifier dense top of vgg
# IN THIS NOTEBOOK WE ADD A BATCH NORMALIZATION LAYER AND WE RISE DROPOUT RATE TO 0.5

supernet.trainable = False

inputs = tfk.Input(shape=(256,256,3))

x = supernet(inputs)

x = tfkl.GlobalAveragePooling2D()(x)

x = tfkl.Dense(
    256,
    kernel_initializer = tfk.initializers.GlorotUniform(seed),
    use_bias=False)(x) #when using batch normalization is good practice to disable bias

x = tfkl.BatchNormalization()(x) # batch normalization layer between dense layer and activation function

x = tfkl.Activation('relu')(x) # relu activation

x = tfkl.Dropout(0.5, seed=seed)(x) # dropout layer acts as regularizers

outputs = tfkl.Dense(
    14, 
    activation='softmax',
    kernel_initializer = tfk.initializers.GlorotUniform(seed))(x)

# Connect input and output through the Model class
tl_model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

# Compile the model
tl_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')
tl_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  vgg16 (Functional)          (None, 8, 8, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               131072
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 14)                3598
#
# =================================================================
# Total params: 14,850,382
# Trainable params: 135,182
# Non-trainable params: 14,715,200
# _________________________________________________________________

# %%
# Considering class imbalance: class weightning
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique(aug_train_gen.classes),
                                        y = aug_train_gen.classes                                                   
                                    )
class_weights = dict(zip(np.unique(aug_train_gen.classes), class_weights))
class_weights
# Out:
# {0: 1.2812895069532237,
#  1: 2.7098930481283423,
#  2: 2.170235546038544,
#  3: 1.050259067357513,
#  4: 0.8684661525278492,
#  5: 0.724446032880629,
#  6: 1.2960358056265984,
#  7: 1.6560457516339868,
#  8: 1.768760907504363,
#  9: 4.78066037735849,
#  10: 0.7838360402165506,
#  11: 2.2032608695652174,
#  12: 1.8803339517625233,
#  13: 0.2225027442371021}

# %%
# Utility function to create folders and callbacks for training
from datetime import datetime

def create_folders_and_callbacks(model_name):

  exps_dir = os.path.join('Experiment_results')

  now = datetime.now().strftime('%b%d_%H-%M-%S')

  exp_dir = os.path.join(exps_dir, model_name + '_' + str(now))
  if not os.path.exists(exp_dir):
      os.makedirs(exp_dir)
      
  callbacks = []

  # Model checkpoint
  # ----------------
  ckpt_dir = os.path.join(exp_dir, 'ckpts')
  if not os.path.exists(ckpt_dir):
      os.makedirs(ckpt_dir)

  ckpt_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(ckpt_dir, 'cp'),
                                                     save_weights_only=False,
                                                     save_best_only=False)
  callbacks.append(ckpt_callback)

  # Early Stopping
  # --------------
  es_callback = tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, restore_best_weights=True)
  callbacks.append(es_callback)

  return callbacks

# %%
# Create folders and callbacks and fit
callbacks = create_folders_and_callbacks(model_name='VGG16_aug_preprocess')

# Train model with classes weighted to overcame class imbalance problems
history = tl_model.fit(
    x = aug_train_gen,
    epochs = epochs,
    validation_data = valid_gen,
    callbacks = callbacks,
    class_weight = class_weights #added class weights here
).history
# Out:
# Epoch 1/200
# 111/111 [==============================] - ETA: 0s - loss: 0.9245 - accuracy: 0.7041 INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 2815s 25s/step - loss: 0.9245 - accuracy: 0.7041 - val_loss: 0.4940 - val_accuracy: 0.8220
# Epoch 2/200
# 111/111 [==============================] - ETA: 0s - loss: 0.3631 - accuracy: 0.8793INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 278s 2s/step - loss: 0.3631 - accuracy: 0.8793 - val_loss: 0.3596 - val_accuracy: 0.8884
# Epoch 3/200
# 111/111 [==============================] - ETA: 0s - loss: 0.2758 - accuracy: 0.9023INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 280s 3s/step - loss: 0.2758 - accuracy: 0.9023 - val_loss: 0.3306 - val_accuracy: 0.8906
# Epoch 4/200
# 111/111 [==============================] - ETA: 0s - loss: 0.2151 - accuracy: 0.9186INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 282s 3s/step - loss: 0.2151 - accuracy: 0.9186 - val_loss: 0.2338 - val_accuracy: 0.9237
# Epoch 5/200
# 111/111 [==============================] - ETA: 0s - loss: 0.2006 - accuracy: 0.9252INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 283s 3s/step - loss: 0.2006 - accuracy: 0.9252 - val_loss: 0.3150 - val_accuracy: 0.8904
# Epoch 6/200
# 111/111 [==============================] - ETA: 0s - loss: 0.1832 - accuracy: 0.9313INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 283s 3s/step - loss: 0.1832 - accuracy: 0.9313 - val_loss: 0.2469 - val_accuracy: 0.9144
# Epoch 7/200
# 111/111 [==============================] - ETA: 0s - loss: 0.1694 - accuracy: 0.9352INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 281s 3s/step - loss: 0.1694 - accuracy: 0.9352 - val_loss: 0.2162 - val_accuracy: 0.9248
# Epoch 8/200
# 111/111 [==============================] - ETA: 0s - loss: 0.1754 - accuracy: 0.9303INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 283s 3s/step - loss: 0.1754 - accuracy: 0.9303 - val_loss: 0.1623 - val_accuracy: 0.9429
# Epoch 9/200
# 111/111 [==============================] - ETA: 0s - loss: 0.1487 - accuracy: 0.9411INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 281s 3s/step - loss: 0.1487 - accuracy: 0.9411 - val_loss: 0.2279 - val_accuracy: 0.9209
# Epoch 10/200
# 111/111 [==============================] - ETA: 0s - loss: 0.1416 - accuracy: 0.9450INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 281s 3s/step - loss: 0.1416 - accuracy: 0.9450 - val_loss: 0.2145 - val_accuracy: 0.9268
# Epoch 11/200
# 111/111 [==============================] - ETA: 0s - loss: 0.1372 - accuracy: 0.9464INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 281s 3s/step - loss: 0.1372 - accuracy: 0.9464 - val_loss: 0.1441 - val_accuracy: 0.9497
# Epoch 12/200
# 111/111 [==============================] - ETA: 0s - loss: 0.1328 - accuracy: 0.9435INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 283s 3s/step - loss: 0.1328 - accuracy: 0.9435 - val_loss: 0.1874 - val_accuracy: 0.9319
# Epoch 13/200
# 111/111 [==============================] - ETA: 0s - loss: 0.1321 - accuracy: 0.9455INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 279s 3s/step - loss: 0.1321 - accuracy: 0.9455 - val_loss: 0.1900 - val_accuracy: 0.9339
# Epoch 14/200
# 111/111 [==============================] - ETA: 0s - loss: 0.1335 - accuracy: 0.9471INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 277s 2s/step - loss: 0.1335 - accuracy: 0.9471 - val_loss: 0.1846 - val_accuracy: 0.9378
# Epoch 15/200
# 111/111 [==============================] - ETA: 0s - loss: 0.1188 - accuracy: 0.9511INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 279s 3s/step - loss: 0.1188 - accuracy: 0.9511 - val_loss: 0.1497 - val_accuracy: 0.9483
# Epoch 16/200
# 111/111 [==============================] - ETA: 0s - loss: 0.1230 - accuracy: 0.9462INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 276s 2s/step - loss: 0.1230 - accuracy: 0.9462 - val_loss: 0.1428 - val_accuracy: 0.9472
# Epoch 17/200
# 111/111 [==============================] - ETA: 0s - loss: 0.1154 - accuracy: 0.9519INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 281s 3s/step - loss: 0.1154 - accuracy: 0.9519 - val_loss: 0.1561 - val_accuracy: 0.9446
# Epoch 18/200
# 111/111 [==============================] - ETA: 0s - loss: 0.1146 - accuracy: 0.9520INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 277s 2s/step - loss: 0.1146 - accuracy: 0.9520 - val_loss: 0.1421 - val_accuracy: 0.9525
# Epoch 19/200
# 111/111 [==============================] - ETA: 0s - loss: 0.1145 - accuracy: 0.9538INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 280s 3s/step - loss: 0.1145 - accuracy: 0.9538 - val_loss: 0.1453 - val_accuracy: 0.9466
# Epoch 20/200
# 111/111 [==============================] - ETA: 0s - loss: 0.1133 - accuracy: 0.9540INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 278s 3s/step - loss: 0.1133 - accuracy: 0.9540 - val_loss: 0.1242 - val_accuracy: 0.9590
# Epoch 21/200
# 111/111 [==============================] - ETA: 0s - loss: 0.1119 - accuracy: 0.9545INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 281s 3s/step - loss: 0.1119 - accuracy: 0.9545 - val_loss: 0.1309 - val_accuracy: 0.9551
# Epoch 22/200
# 111/111 [==============================] - ETA: 0s - loss: 0.1061 - accuracy: 0.9553INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 280s 3s/step - loss: 0.1061 - accuracy: 0.9553 - val_loss: 0.1609 - val_accuracy: 0.9435
# Epoch 23/200
# 111/111 [==============================] - ETA: 0s - loss: 0.1086 - accuracy: 0.9546INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 281s 3s/step - loss: 0.1086 - accuracy: 0.9546 - val_loss: 0.1595 - val_accuracy: 0.9474
# Epoch 24/200
# 111/111 [==============================] - ETA: 0s - loss: 0.1013 - accuracy: 0.9587INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 281s 3s/step - loss: 0.1013 - accuracy: 0.9587 - val_loss: 0.1551 - val_accuracy: 0.9441
# Epoch 25/200
# 111/111 [==============================] - ETA: 0s - loss: 0.1028 - accuracy: 0.9535INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 280s 3s/step - loss: 0.1028 - accuracy: 0.9535 - val_loss: 0.1091 - val_accuracy: 0.9641
# Epoch 26/200
# 111/111 [==============================] - ETA: 0s - loss: 0.1062 - accuracy: 0.9545INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 280s 3s/step - loss: 0.1062 - accuracy: 0.9545 - val_loss: 0.1609 - val_accuracy: 0.9452
# Epoch 27/200
# 111/111 [==============================] - ETA: 0s - loss: 0.0982 - accuracy: 0.9554INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 281s 3s/step - loss: 0.0982 - accuracy: 0.9554 - val_loss: 0.1755 - val_accuracy: 0.9404
# Epoch 28/200
# 111/111 [==============================] - ETA: 0s - loss: 0.0956 - accuracy: 0.9561INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 281s 3s/step - loss: 0.0956 - accuracy: 0.9561 - val_loss: 0.1689 - val_accuracy: 0.9472
# Epoch 29/200
# 111/111 [==============================] - ETA: 0s - loss: 0.0976 - accuracy: 0.9560INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 277s 2s/step - loss: 0.0976 - accuracy: 0.9560 - val_loss: 0.1397 - val_accuracy: 0.9491
# Epoch 30/200
# 111/111 [==============================] - ETA: 0s - loss: 0.0887 - accuracy: 0.9574INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 276s 2s/step - loss: 0.0887 - accuracy: 0.9574 - val_loss: 0.1365 - val_accuracy: 0.9517
# Epoch 31/200
# 111/111 [==============================] - ETA: 0s - loss: 0.0922 - accuracy: 0.9614INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 277s 2s/step - loss: 0.0922 - accuracy: 0.9614 - val_loss: 0.1380 - val_accuracy: 0.9537
# Epoch 32/200
# 111/111 [==============================] - ETA: 0s - loss: 0.0956 - accuracy: 0.9585INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 273s 2s/step - loss: 0.0956 - accuracy: 0.9585 - val_loss: 0.1408 - val_accuracy: 0.9522
# Epoch 33/200
# 111/111 [==============================] - ETA: 0s - loss: 0.0868 - accuracy: 0.9613INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 277s 2s/step - loss: 0.0868 - accuracy: 0.9613 - val_loss: 0.1355 - val_accuracy: 0.9525
# Epoch 34/200
# 111/111 [==============================] - ETA: 0s - loss: 0.0873 - accuracy: 0.9617INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 297s 3s/step - loss: 0.0873 - accuracy: 0.9617 - val_loss: 0.1393 - val_accuracy: 0.9508
# Epoch 35/200
# 111/111 [==============================] - ETA: 0s - loss: 0.0896 - accuracy: 0.9612INFO:tensorflow:Assets written to: Experiment_results/VGG16_aug_preprocess_Nov21_11-15-49/ckpts/cp/assets
# 111/111 [==============================] - 299s 3s/step - loss: 0.0896 - accuracy: 0.9612 - val_loss: 0.1793 - val_accuracy: 0.9378

# %%
tl_model.save("Experiment results/VGG16_data_aug_preprocess")
# Out:
# INFO:tensorflow:Assets written to: Experiment results/VGG16_data_aug_preprocess/assets

# %%
# Plot the training
plt.figure(figsize=(15,5))
plt.plot(history['loss'], label='Training', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], label='Training', alpha=.8, color='#ff7f0e')
plt.plot(history['val_accuracy'], label='Validation', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %% [markdown]
# # Fine-Tuning

# %%
# Re-load the model after transfer learning
ft_model = tfk.models.load_model('Experiment results/VGG16_data_aug_preprocess')
ft_model.summary()

# %%
# Set all VGG layers to trainable
ft_model.get_layer('vgg16').trainable = True
for i, layer in enumerate(ft_model.get_layer('vgg16').layers):
   print(i, layer.name, layer.trainable)

# %%
# Freeze first 15 layers
for i, layer in enumerate(ft_model.get_layer('vgg16').layers[:15]):
  layer.trainable=False

for i, layer in enumerate(ft_model.get_layer('vgg16').layers):
   print(i, layer.name, layer.trainable)
ft_model.summary()

# %%
# Compile the model
ft_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(1e-4), metrics='accuracy')

# %%
# re check class weigths
class_weights

# %%
# Create folders and callbacks and fit
ft_callbacks = create_folders_and_callbacks(model_name='VGG16_aug_preprocess_finetuned')

# Train model with classes weighted to overcame class imbalance problems
history = ft_model.fit(
    x = aug_train_gen,
    epochs = epochs,
    validation_data = valid_gen,
    callbacks = ft_callbacks,
    class_weight = class_weights #added class weights here
).history

# %%
# this model seems a good starting point :). Let's save it!
ft_model.save("Experiment results/VGG16_aug_finetuned_preprocessing")

# %%
# Plot the training
plt.figure(figsize=(15,5))
plt.plot(history['loss'], label='Training', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], label='Training', alpha=.8, color='#ff7f0e')
plt.plot(history['val_accuracy'], label='Validation', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()
